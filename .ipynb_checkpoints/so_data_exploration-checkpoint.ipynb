# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.api.types import CategoricalDtype

# %% [markdown]
# Some exploration Ideas:
#
# - https://www.kaggle.com/willcanniford/so-developer-survey-insights-visualisations/notebook
# - https://www.kaggle.com/pmarcelino/comprehensive-data-exploration-with-python

# %%
df = pd.read_csv('./stack-overflow-2018-developer-survey/survey_results_public.tar.gz', low_memory=False)
header = pd.read_csv('./stack-overflow-2018-developer-survey/survey_results_schema.csv', low_memory=False)

# %%
# View all possible values in a column, in this dataset, list of checkbox is separated with ;
def get_unique_categories(column):
  return set([x for c in df[column].dropna().unique() for x in c.split(';')])

# %%
get_unique_categories('RaceEthnicity')
# Out:
# {'Black or of African descent',
#  'East Asian',
#  'Hispanic or Latino/Latina',
#  'Middle Eastern',
#  'Native American, Pacific Islander, or Indigenous Australian',
#  'South Asian',
#  'White or of European descent'}

# %%
df['HoursOutside'].value_counts()
# Out:
# 1 - 2 hours             27788
# 30 - 59 minutes         24002
# Less than 30 minutes    11223
# 3 - 4 hours              7186
# Over 4 hours             1825
# Name: HoursOutside, dtype: int64

# %%
_ = df['CareerSatisfaction'].value_counts().plot(kind='bar', title='Career Satisfaction')

# %%
_ = df['JobSatisfaction'].value_counts().plot(kind='bar', title='Job Satisfaction')

# %%
_ = df['Age'].value_counts().plot(kind='bar', title='Age')

# %%
_ = df['CompanySize'].value_counts().plot(kind='bar', title='CompanySize')

# %% [markdown]
# ## Exploration

# %% [markdown]
# ### Interesting columns

# %%
columns_of_interests = [
  'Hobby', 
  'OpenSource', 
  'Country', 
  'Student',
  'Employment', 
  'FormalEducation', 
  'UndergradMajor', 
  'CompanySize',
  'DevType', 
  'YearsCoding', 
  'YearsCodingProf', 
  'JobSatisfaction',
  'CareerSatisfaction', 
  'JobSearchStatus',
  'LastNewJob',
  'Gender',
  'SexualOrientation',
  'Age'
  # 'ConvertedSalary' Only half of dataset not nan
]

# %%
df[columns_of_interests]
# Out:
#       Hobby OpenSource                       Country         Student  \
# 0       Yes         No                         Kenya              No
# 1       Yes        Yes                United Kingdom              No
# 2       Yes        Yes                 United States              No
# 3        No         No                 United States              No
# 4       Yes         No                  South Africa  Yes, part-time
# 5       Yes         No                United Kingdom              No
# 6       Yes        Yes                 United States              No
# 7       Yes        Yes                       Nigeria              No
# 8       Yes        Yes                 United States              No
# 9        No        Yes                         India              No
# 10      Yes         No                         Spain              No
# 11      Yes        Yes                         India              No
# 12      Yes         No                       Croatia             NaN
# ...

# %%
from ipywidgets import interact

@interact(cat=columns_of_interests)
def g(cat):
    return df[cat].value_counts().plot(kind='bar')
# Out:
# interactive(children=(Dropdown(description='cat', options=('Hobby', 'OpenSource', 'Country', 'Student', 'Emplo…

# %%
df[columns_of_interests].shape
# Out:
# (98855, 18)

# %% [markdown]
# ### Convert JobSatisfaction to numerical

# %%
# Do it manually since we want to maintain the order/number. 
career_satisfactions = [
  'Extremely dissatisfied',
  'Moderately dissatisfied',
  'Slightly dissatisfied',
  'Neither satisfied nor dissatisfied',
  'Slightly satisfied',
  'Moderately satisfied',
  'Extremely satisfied']

cats = CategoricalDtype(categories=career_satisfactions, ordered=True)
df['CareerSatisfaction'] = df['CareerSatisfaction'].astype(cats)
df['CareerSatisfactionCode'] = df['CareerSatisfaction'].cat.codes - 3
df['JobSatisfaction'] = df['JobSatisfaction'].astype(cats)
df['JobSatisfactionCode'] = df['JobSatisfaction'].cat.codes - 3

# %% [markdown]
# After convert:

# %%
df[['JobSatisfaction', 'JobSatisfactionCode']]
# Out:
#                           JobSatisfaction  JobSatisfactionCode
# 0                     Extremely satisfied                    3
# 1                 Moderately dissatisfied                   -2
# 2                    Moderately satisfied                    2
# 3      Neither satisfied nor dissatisfied                    0
# 4                      Slightly satisfied                    1
# 5                    Moderately satisfied                    2
# 6                      Slightly satisfied                    1
# 7                      Slightly satisfied                    1
# 8                    Moderately satisfied                    2
# 9                                     NaN                   -4
# 10                Moderately dissatisfied                   -2
# 11                                    NaN                   -4
# 12                                    NaN                   -4
# 13                    Extremely satisfied                    3
# ...

# %% [markdown]
# ## Predictive Task

# %% [markdown]
# Given some features like 'hobby', 'companysize', 'devtype', 'is doing opensource', predict career/job satisfaction.
